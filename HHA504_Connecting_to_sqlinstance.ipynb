# %% [markdown]
# <a href="https://colab.research.google.com/github/Alherrera2798/HHA504_Database_e2e_Final/blob/main/HHA504_Connecting_to_sqlinstance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sqlalchemy import create_engine
import sqlalchemy
import pandas as pd
import pymysql as db

# %%
# !pip install mysql

# %%
# !pip install cryptography

# %%
# !pip install django-cryptographic-fields

# %%
# !pip install PyMySQL[rsa]

# %%
MYSQL_HOSTNAME = '20.127.54.159' 
MYSQL_USER = 'DBA'
MYSQL_PASSWORD = 'ahi2021'
MYSQL_DATABASE = 'e2e'

# %%
connection_string = f'mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOSTNAME}/{MYSQL_DATABASE}'
engine = create_engine(connection_string)

# %%
connection_string
# Out:
# 'mysql+pymysql://DBA:ahi2021@20.127.54.159/e2e'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a0214f5-42fb-478f-929c-c4d9f06d2cb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a0214f5-42fb-478f-929c-c4d9f06d2cb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving H1N1.csv to H1N1 (1).csv

# %%
import io
import pandas as pd
h1n1df= pd.read_csv(io.BytesIO(uploaded['H1N1.csv']))

# %%
h1n1df
# Out:
#        respondent_id  h1n1_concern  ...  h1n1_vaccine  seasonal_vaccine
# 0                  0           1.0  ...             0                 0
# 1                  1           3.0  ...             0                 1
# 2                  2           1.0  ...             0                 0
# 3                  3           1.0  ...             0                 1
# 4                  4           2.0  ...             0                 0
# ...              ...           ...  ...           ...               ...
# 26702          26702           2.0  ...             0                 0
# 26703          26703           1.0  ...             0                 0
# 26704          26704           2.0  ...             0                 1
# 26705          26705           1.0  ...             0                 0
# 26706          26706           0.0  ...             0                 0
#
# [26707 rows x 38 columns]

# %%
h1n1df.to_sql('H1N1.csv', con=engine, if_exists ='append')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pymysql/connections.py in connect(self, sock)
#     613                             sock = socket.create_connection(
# --> 614                                 (self.host, self.port), self.connect_timeout, **kwargs
#     615                             )
#
# /usr/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     727         try:
# --> 728             raise err
#     729         finally:
#
# /usr/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...
